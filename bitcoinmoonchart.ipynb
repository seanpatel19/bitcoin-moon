# %%
import pandas as pd
import holoviews as hv
import hvplot.pandas
import datetime as dt
import numpy as np
        ### imported numpys to get a better looking heatmap 
# %matplotlib inline

# %%
df_btc_moon = pd.read_csv(
                                "bitcoin moon.csv",
                                index_col="date",
                                parse_dates=True,
                                infer_datetime_format=True)

# %% [markdown]
# df_btc_moon.head(73)

# %%
df_btc_moon.head(73)
# Out:
#                  new price open new price close    t+1 new    t+2 new  \
# date
# 1/9/16 -1/23/16          453.38          447.61     447.99     448.43
# 2/8/16-2/22/16           376.76          373.33     376.03     381.65
# 3/8/16-3/23/16           414.56          413.97     414.86     417.13
# 4/7/16-4/22/16           423.62          422.74     420.35     419.41
# 5/6/16-5/21/16           447.94           459.6     458.54     458.55
# ...                         ...             ...        ...        ...
# 7/9/21-7/23/21        32,861.67       33,798.01  33,520.52  34,240.19
# 8/8/21-8/22/21        44,574.44       43,798.12  46,365.40  45,585.03
# 9/6/21-9/20/21        51,769.00       52,633.54  46,811.13  46,091.39
# 10/6/21-10/20/21      51,486.66       55,361.45  53,805.98  53,967.85
# 11/4/21-11/19/21      62,941.80       61,452.23  61,125.68  61,527.48
#
#                    t+3 new    t+4 new    t+5 new     t+6 new full price open  \
# date
# ...
